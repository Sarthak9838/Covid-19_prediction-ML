# %%
import pandas as p
import numpy as n

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data = p.read_csv('covid.csv')

# %%
data.head(10)
# Out:
#          id  sex  patient_type  entry_date date_symptoms   date_died  intubed  \
# 0    16169f    2             1  04-05-2020    02-05-2020  9999-99-99       97
# 1    1009bf    2             1  19-03-2020    17-03-2020  9999-99-99       97
# 2    167386    1             2  06-04-2020    01-04-2020  9999-99-99        2
# 3    0b5948    2             2  17-04-2020    10-04-2020  9999-99-99        2
# 4    0d01b5    1             2  13-04-2020    13-04-2020  22-04-2020        2
# 5    1beec8    2             2  16-04-2020    16-04-2020  29-04-2020        2
# 6  1.75E+56    2             2  22-04-2020    13-04-2020  9999-99-99        2
# 7    0ce1f5    1             1  21-05-2020    18-05-2020  9999-99-99       97
# 8    12b57a    1             1  22-04-2020    18-04-2020  9999-99-99       97
# 9    006b91    1             2  23-04-2020    18-04-2020  9999-99-99        1
#
#    pneumonia  age  pregnancy  ...  inmsupr  hypertension  other_disease  \
# ...

# %%
data.shape
# Out:
# (566602, 23)

# %%
df=data.dropna()

# %%
df.shape
# Out:
# (566602, 23)

# %%
df.describe()
# Out:
#                  sex   patient_type        intubed      pneumonia  \
# count  566602.000000  566602.000000  566602.000000  566602.000000
# mean        1.506726       1.215165      76.562952       1.846262
# std         0.499955       0.410937      39.058676       0.560939
# min         1.000000       1.000000       1.000000       1.000000
# 25%         1.000000       1.000000      97.000000       2.000000
# 50%         2.000000       1.000000      97.000000       2.000000
# 75%         2.000000       1.000000      97.000000       2.000000
# max         2.000000       2.000000      99.000000      99.000000
#
#                  age      pregnancy       diabetes           copd  \
# count  566602.000000  566602.000000  566602.000000  566602.000000
# mean       42.622483      50.400692       2.210633       2.280221
# std        16.659973      47.501579       5.683523       5.327832
# min         0.000000       1.000000       1.000000       1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 566602 entries, 0 to 566601
# Data columns (total 23 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   566602 non-null  object
#  1   sex                  566602 non-null  int64
#  2   patient_type         566602 non-null  int64
#  3   entry_date           566602 non-null  object
#  4   date_symptoms        566602 non-null  object
#  5   date_died            566602 non-null  object
#  6   intubed              566602 non-null  int64
#  7   pneumonia            566602 non-null  int64
#  8   age                  566602 non-null  int64
#  9   pregnancy            566602 non-null  int64
#  10  diabetes             566602 non-null  int64
#  11  copd                 566602 non-null  int64
#  12  asthma               566602 non-null  int64
#  13  inmsupr              566602 non-null  int64
#  14  hypertension         566602 non-null  int64
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 566597    False
# 566598    False
# 566599    False
# 566600    False
# 566601    False
# Length: 566602, dtype: bool

# %%
sum(df.duplicated())
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# id                     0
# sex                    0
# patient_type           0
# entry_date             0
# date_symptoms          0
# date_died              0
# intubed                0
# pneumonia              0
# age                    0
# pregnancy              0
# diabetes               0
# copd                   0
# asthma                 0
# inmsupr                0
# hypertension           0
# other_disease          0
# cardiovascular         0
# obesity                0
# renal_chronic          0
# tobacco                0
# contact_other_covid    0
# covid_res              0
# icu                    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'sex', 'patient_type', 'entry_date', 'date_symptoms', 'date_died',
#        'intubed', 'pneumonia', 'age', 'pregnancy', 'diabetes', 'copd',
#        'asthma', 'inmsupr', 'hypertension', 'other_disease', 'cardiovascular',
#        'obesity', 'renal_chronic', 'tobacco', 'contact_other_covid',
#        'covid_res', 'icu'],
#       dtype='object')

# %%
df['covid_res'].value_counts().to_frame()
# Out:
#    covid_res
# 2     279035
# 1     220657
# 3      66910

# %%
df['covid_res'].replace([1,2,3],[0,1,2],inplace=True)
df['covid_res'].value_counts().to_frame()
# Out:
#    covid_res
# 1     279035
# 0     220657
# 2      66910

# %%
df.rename(columns={'covid_res':'Chance'},inplace=True)
df.head()
# Out:
#        id  sex  patient_type  entry_date date_symptoms   date_died  intubed  \
# 0  16169f    2             1  04-05-2020    02-05-2020  9999-99-99       97
# 1  1009bf    2             1  19-03-2020    17-03-2020  9999-99-99       97
# 2  167386    1             2  06-04-2020    01-04-2020  9999-99-99        2
# 3  0b5948    2             2  17-04-2020    10-04-2020  9999-99-99        2
# 4  0d01b5    1             2  13-04-2020    13-04-2020  22-04-2020        2
#
#    pneumonia  age  pregnancy  ...  inmsupr  hypertension  other_disease  \
# 0          2   27         97  ...        2             2              2
# 1          2   24         97  ...        2             2              2
# 2          2   54          2  ...        2             2              2
# 3          1   30         97  ...        2             2              2
# 4          2   60          2  ...        2             1              2
#
#    cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# ...

# %%
df=df[df['Chance']!=2]

# %%
lst=df.columns
for i in range(23):
    print(df[lst[i]].value_counts().to_frame())
    print("----------------")
# Out:
#            id
# 0.00E+00  186
# 1.56E+03    9
# 1.50E+09    9
# 1.80E+07    9
# 1.92E+04    8
# ...       ...
# 0b189d      1
# 1b9ca7      1
# 0720b8      1
# 35183       1
# 121d38      1
#
# [496836 rows x 1 columns]
# ----------------
#       sex
# 2  253098
# 1  246594
# ----------------
#    patient_type
# 1        392146
# 2        107546
# ----------------
#             entry_date
# 15-06-2020       12008
# 16-06-2020       11611
# 12-06-2020       11234
# 08-06-2020       11136
# 17-06-2020       11053
# ...                ...
# 08-02-2020           8
# 01-02-2020           8
# 04-01-2020           6
# 01-01-2020           5
# 11-01-2020           5
#
# [181 rows x 1 columns]
# ----------------
#             date_symptoms
# 01-06-2020          12988
# 10-06-2020          11682
# 15-06-2020          11440
# 25-05-2020          10164
# 08-06-2020          10111
# ...                   ...
# 04-01-2020             19
# 03-01-2020             16
# 31-01-2020             15
# ...

# %%
df.reset_index(drop=True,inplace=True)
df.head(10)
# Out:
#          id  sex  patient_type  entry_date date_symptoms   date_died  intubed  \
# 0    16169f    2             1  04-05-2020    02-05-2020  9999-99-99       97
# 1    1009bf    2             1  19-03-2020    17-03-2020  9999-99-99       97
# 2    167386    1             2  06-04-2020    01-04-2020  9999-99-99        2
# 3    0b5948    2             2  17-04-2020    10-04-2020  9999-99-99        2
# 4    0d01b5    1             2  13-04-2020    13-04-2020  22-04-2020        2
# 5    1beec8    2             2  16-04-2020    16-04-2020  29-04-2020        2
# 6  1.75E+56    2             2  22-04-2020    13-04-2020  9999-99-99        2
# 7    0ce1f5    1             1  21-05-2020    18-05-2020  9999-99-99       97
# 8    12b57a    1             1  22-04-2020    18-04-2020  9999-99-99       97
# 9    006b91    1             2  23-04-2020    18-04-2020  9999-99-99        1
#
#    pneumonia  age  pregnancy  ...  inmsupr  hypertension  other_disease  \
# ...

# %%
print(" Chance range :", sorted(df['Chance'].unique()))
# Out:
#  Chance range : [0, 1]

# %%
df.Chance.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
p.Categorical(df['Chance']).describe()
# Out:
#             counts     freqs
# categories
# 0           220657  0.441586
# 1           279035  0.558414

# %%
df.head()
# Out:
#        id  sex  patient_type  entry_date date_symptoms   date_died  intubed  \
# 0  16169f    2             1  04-05-2020    02-05-2020  9999-99-99       97
# 1  1009bf    2             1  19-03-2020    17-03-2020  9999-99-99       97
# 2  167386    1             2  06-04-2020    01-04-2020  9999-99-99        2
# 3  0b5948    2             2  17-04-2020    10-04-2020  9999-99-99        2
# 4  0d01b5    1             2  13-04-2020    13-04-2020  22-04-2020        2
#
#    pneumonia  age  pregnancy  ...  inmsupr  hypertension  other_disease  \
# 0          2   27         97  ...        2             2              2
# 1          2   24         97  ...        2             2              2
# 2          2   54          2  ...        2             2              2
# 3          1   30         97  ...        2             2              2
# 4          2   60          2  ...        2             1              2
#
#    cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
var_mod =['id', 'sex', 'patient_type', 'entry_date', 'date_symptoms', 'date_died',
       'intubed', 'pneumonia', 'age', 'pregnancy', 'diabetes', 'copd',
       'asthma', 'inmsupr', 'hypertension', 'other_disease', 'cardiovascular',
       'obesity', 'renal_chronic', 'tobacco', 'contact_other_covid', 'Chance',
       'icu']
le = LabelEncoder()
for i in var_mod:
    df[i] = le.fit_transform(df[i]).astype(str)

# %%
df.head()
# Out:
#        id sex patient_type entry_date date_symptoms date_died intubed  \
# 0  332961   1            0         22            10       123       2
# 1  235774   1            0        110            98       123       2
# 2  338816   0            1         33             3       123       1
# 3  155272   1            1         99            57       123       1
# 4  182375   0            1         75            75        82       1
#
#   pneumonia age pregnancy  ... inmsupr hypertension other_disease  \
# 0         1  27         2  ...       1            1             1
# 1         1  24         2  ...       1            1             1
# 2         1  54         1  ...       1            1             1
# 3         0  30         2  ...       1            1             1
# 4         1  60         1  ...       1            0             1
#
#   cardiovascular obesity renal_chronic tobacco contact_other_covid Chance icu
# ...
